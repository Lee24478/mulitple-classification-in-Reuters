# %%
from tensorflow.keras.datasets import reuters  # 匯入 reuters 資料集

(a_train, b_train),(a_test, b_test) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.preprocessing.text import Tokenizer  

tok = Tokenizer(num_words=10000)           #←指定字典的總字數
x_train = tok.sequences_to_matrix(a_train) #←將訓練樣本做 multi-hot 編碼
x_test  = tok.sequences_to_matrix(a_test)  #←將測試樣本做 multi-hot 編碼

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(b_train)  #←將訓練標籤轉為 one-hot 編碼
y_test  = to_categorical(b_test)   #←將測試標籤轉為 one-hot 編碼

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, activation='relu', input_dim=10000))
model.add(Dense(64, activation='relu'))
model.add(Dense(46, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['acc'])
history = model.fit(x_train, y_train,
                    batch_size=512,
                    epochs=20,            #← 訓練 20 個週期
                    verbose=2,     #←顯示精簡訊息 (無進度條)
                    validation_split=0.2) #← 由訓練資料切出 20% 做驗證
# Out:
# Epoch 1/20
# 15/15 - 2s - loss: 2.8986 - acc: 0.4864 - val_loss: 1.9676 - val_acc: 0.6311 - 2s/epoch - 119ms/step
# Epoch 2/20
# 15/15 - 1s - loss: 1.5998 - acc: 0.6856 - val_loss: 1.4383 - val_acc: 0.6917 - 729ms/epoch - 49ms/step
# Epoch 3/20
# 15/15 - 1s - loss: 1.1524 - acc: 0.7531 - val_loss: 1.3042 - val_acc: 0.6928 - 699ms/epoch - 47ms/step
# Epoch 4/20
# 15/15 - 1s - loss: 0.9155 - acc: 0.8077 - val_loss: 1.1512 - val_acc: 0.7446 - 697ms/epoch - 46ms/step
# Epoch 5/20
# 15/15 - 1s - loss: 0.7492 - acc: 0.8430 - val_loss: 1.0451 - val_acc: 0.7629 - 693ms/epoch - 46ms/step
# Epoch 6/20
# 15/15 - 1s - loss: 0.6128 - acc: 0.8749 - val_loss: 1.0193 - val_acc: 0.7846 - 688ms/epoch - 46ms/step
# Epoch 7/20
# 15/15 - 1s - loss: 0.4980 - acc: 0.8995 - val_loss: 0.9877 - val_acc: 0.7869 - 697ms/epoch - 46ms/step
# Epoch 8/20
# 15/15 - 1s - loss: 0.4058 - acc: 0.9198 - val_loss: 0.9599 - val_acc: 0.7869 - 687ms/epoch - 46ms/step
# Epoch 9/20
# 15/15 - 1s - loss: 0.3315 - acc: 0.9333 - val_loss: 0.9553 - val_acc: 0.7930 - 685ms/epoch - 46ms/step
# Epoch 10/20
# 15/15 - 1s - loss: 0.2767 - acc: 0.9415 - val_loss: 0.9389 - val_acc: 0.7963 - 683ms/epoch - 46ms/step
# Epoch 11/20
# 15/15 - 1s - loss: 0.2337 - acc: 0.9485 - val_loss: 0.9333 - val_acc: 0.8024 - 678ms/epoch - 45ms/step
# Epoch 12/20
# 15/15 - 1s - loss: 0.2023 - acc: 0.9537 - val_loss: 0.9466 - val_acc: 0.8097 - 684ms/epoch - 46ms/step
# Epoch 13/20
# 15/15 - 1s - loss: 0.1717 - acc: 0.9562 - val_loss: 1.0947 - val_acc: 0.7702 - 685ms/epoch - 46ms/step
# Epoch 14/20
# 15/15 - 1s - loss: 0.1593 - acc: 0.9592 - val_loss: 0.9841 - val_acc: 0.7986 - 698ms/epoch - 47ms/step
# Epoch 15/20
# 15/15 - 1s - loss: 0.1425 - acc: 0.9601 - val_loss: 1.0587 - val_acc: 0.7963 - 676ms/epoch - 45ms/step
# Epoch 16/20
# 15/15 - 1s - loss: 0.1329 - acc: 0.9610 - val_loss: 1.1056 - val_acc: 0.7952 - 701ms/epoch - 47ms/step
# Epoch 17/20
# 15/15 - 1s - loss: 0.1280 - acc: 0.9598 - val_loss: 1.0590 - val_acc: 0.8019 - 684ms/epoch - 46ms/step
# Epoch 18/20
# 15/15 - 1s - loss: 0.1151 - acc: 0.9627 - val_loss: 1.0580 - val_acc: 0.8008 - 683ms/epoch - 46ms/step
# Epoch 19/20
# 15/15 - 1s - loss: 0.1055 - acc: 0.9644 - val_loss: 1.0966 - val_acc: 0.7974 - 692ms/epoch - 46ms/step
# Epoch 20/20
# 15/15 - 1s - loss: 0.1071 - acc: 0.9623 - val_loss: 1.1424 - val_acc: 0.7902 - 671ms/epoch - 45ms/step

# %%
loss, acc = model.evaluate(x_test, y_test, verbose=2)  #←評估訓練成效
print('評估測試資料的準確率 =', acc)
# Out:
# 71/71 - 0s - loss: 1.1677 - acc: 0.7867 - 186ms/epoch - 3ms/step
# 評估測試資料的準確率 = 0.7867319583892822
